# %%
import yfinance as yf
import pandas as pd

# Set the start and end date
start_date = '2016-01-01'
end_date = '2021-01-01'

# Define the ticker list
tickers_list = ['ADANIPORTS.NS','ASIANPAINT.NS','AXISBANK.NS','BAJAJ-AUTO.NS','BAJAJFINSV.NS','BAJFINANCE.NS',
'BHARTIARTL.NS','BPCL.NS','BRITANNIA.NS','CIPLA.NS','COALINDIA.NS','DIVISLAB.NS','DRREDDY.NS','EICHERMOT.NS','GAIL.NS',
'GRASIM.NS','HCLTECH.NS','HDFC.NS','HDFCBANK.NS','HEROMOTOCO.NS','HINDALCO.NS','HINDUNILVR.NS','ICICIBANK.NS',
'INDUSINDBK.NS','INFY.NS','IOC.NS','ITC.NS','JSWSTEEL.NS','KOTAKBANK.NS','LT.NS','M&M.NS',
'MARUTI.NS','NESTLEIND.NS','NTPC.NS','ONGC.NS','POWERGRID.NS','RELIANCE.NS','SBIN.NS',
'SHREECEM.NS','SUNPHARMA.NS','TATAMOTORS.NS','TATASTEEL.NS','TCS.NS','TECHM.NS','TITAN.NS','ULTRACEMCO.NS',
'UPL.NS','WIPRO.NS']

# Create placeholder for data
df = pd.DataFrame(columns=tickers_list)

# Fetch the data
for ticker in tickers_list:
    df[ticker] = yf.download(ticker, 
                               start_date,
                               end_date)['Adj Close']
    
# Print first 5 rows of the data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             ADANIPORTS.NS  ASIANPAINT.NS  AXISBANK.NS  BAJAJ-AUTO.NS  \
# Date
# 2016-01-01     259.295502     845.420410   440.847717    2136.001953
# 2016-01-04     249.991730     847.392639   429.579071    2106.609131
# 2016-01-05     247.811111     866.489868   427.668335    2122.726562
# 2016-01-06     244.031433     852.780151   422.034027    2108.432373
# 2016-01-07     237.441223     839.263184   401.015594    2052.233398
#
#             BAJAJFINSV.NS  BAJFINANCE.NS  BHARTIARTL.NS     BPCL.NS  \
# Date
# 2016-01-01    1978.063721     601.376648     303.169037  199.473007
# 2016-01-04    1953.833984     597.095032     290.971069  198.448990
# 2016-01-05    1940.372925     591.708618     287.988342  200.942245
# 2016-01-06    1932.944580     602.501160     286.875397  203.090530
# 2016-01-07    1921.477783     602.407532     287.008972  196.846191
#
#             BRITANNIA.NS    CIPLA.NS  ...   SHREECEM.NS  SUNPHARMA.NS  \
# Date                                  ...
# 2016-01-01   1374.428101  638.705994  ...  11097.268555    785.218445
# 2016-01-04   1368.077271  629.252380  ...  10781.172852    769.380249
# 2016-01-05   1365.361938  624.574280  ...  10844.538086    770.728210
# 2016-01-06   1381.469971  635.538452  ...  11164.334961    762.496277
# 2016-01-07   1356.088257  621.260559  ...  10702.843750    754.649292
#
#             TATAMOTORS.NS  TATASTEEL.NS       TCS.NS    TECHM.NS    TITAN.NS  \
# Date
# 2016-01-01     401.737305    215.094711  1077.589966  444.897156  340.026611
# 2016-01-04     376.897339    214.676895  1056.719238  441.774628  339.398773
# 2016-01-05     374.298431    229.217102  1047.510620  446.479828  335.825195
# 2016-01-06     365.751862    224.579269  1062.070679  449.217438  335.970062
# 2016-01-07     343.410919    208.827393  1057.455322  436.983856  332.299805
#
#             ULTRACEMCO.NS      UPL.NS    WIPRO.NS
# Date
# 2016-01-01    2772.252686  276.159393  202.975677
# 2016-01-04    2698.774414  272.083038  203.431610
# 2016-01-05    2682.969482  272.992340  203.139816
# 2016-01-06    2685.178223  278.040771  202.483215
# 2016-01-07    2618.816650  261.766602  200.568176
#
# [5 rows x 48 columns]

# %%
name=list(df)
name
# Out:
# ['ADANIPORTS.NS',
#  'ASIANPAINT.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJFINSV.NS',
#  'BAJFINANCE.NS',
#  'BHARTIARTL.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'DIVISLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'GAIL.NS',
#  'GRASIM.NS',
#  'HCLTECH.NS',
#  'HDFC.NS',
#  'HDFCBANK.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HINDUNILVR.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'INFY.NS',
#  'IOC.NS',
#  'ITC.NS',
#  'JSWSTEEL.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'M&M.NS',
#  'MARUTI.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'POWERGRID.NS',
#  'RELIANCE.NS',
#  'SBIN.NS',
#  'SHREECEM.NS',
#  'SUNPHARMA.NS',
#  'TATAMOTORS.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'WIPRO.NS']

# %%
df1=df.copy()

# %%
def CAGR(df,name):
    start_value = df[name].iloc[0] #USING df[name] and iloc function, identify the initial price of stock 
    end_value = df[name].iloc[-1] #Like we did for Start Value, USING df[name] and iloc function, identify the final price of stock 
    n = 6 #Specify the Number of years we are taking into account 
    cagr = (end_value/start_value)**(1/n) -1 #WRITE THE CAGR FUNCTION USING START VALUE, END VALUE AND NUMBER OF PERIODS
     
    return cagr

# %%
import numpy as np

def volatility(df,name):
    df[name] = df[name].pct_change()
    vol = df[name].std(ddof=0) * np.sqrt(252)
    return vol

# %%
def sharpe(x,y,rf):
    sr = (x - 0.06)/y#Sharpe Ratio formula using CAGR, Volatility and Risk-Free rate
    
    return sr

# %%
cagr = []
vol = []
sr = []
rf = 0.06
for i in range(len(name)):
    x = CAGR(df, name[i])
    y = volatility(df, name[i])
    z = sharpe(x,y,rf)
    cagr.append(x)
    vol.append(y)
    sr.append(z)

#PRINT CAGR, VOL, SR LIST
print(sr)
# Out:
# [0.13288634701930327, 0.6127217564023414, -0.0036179767320470993, 0.06429917288618403, 0.6124186892002532, 0.901212157698814, 0.08820144681682837, 0.07532112126501633, 0.4094572201789159, -0.06521585062089029, -0.49240422938926215, 0.47627114018261696, 0.1303414383865922, 0.06929595502705911, -0.02075886624041353, 0.07831486691063756, 0.35656295551207595, 0.2661479343075003, 0.51313780756489, -0.020954125702550935, 0.3233877864800001, 0.6067776007941721, 0.2531008061211584, -0.1460354747349481, 0.3994331545212847, -0.14406294120433988, -0.1789741772059103, 0.5707787836694992, 0.4358727162537371, 0.09839048840634321, -0.09559759775224204, 0.11881920839381264, 0.6712614105062668, -0.22671698482647595, -0.3345806023786317, 0.10111970623610453, 0.6630736075545791, -0.06352996148242729, 0.25420603448589946, -0.32688004107984275, -0.39201121889668983, 0.35670583461072963, 0.44273251682474013, 0.23470515720678795, 0.6730478312297303, 0.18257358526046846, 0.07846374749306273, 0.20500916809305839]

# %% [markdown]
# ##### Identifying the top 10 stocks in NIFTY50

# %%
df0 = pd.DataFrame(name)
df0["Sharpe Ratio"] = sr 
#Top_10 = sr.sort_values(ascending = False).head(10)
df0.sort_values(by = "Sharpe Ratio", ascending = False, inplace = True)
top_10 = df0.head(10)
top_10
# Out:
#                 0  Sharpe Ratio
# 5   BAJFINANCE.NS      0.901212
# 44       TITAN.NS      0.673048
# 32   NESTLEIND.NS      0.671261
# 36    RELIANCE.NS      0.663074
# 1   ASIANPAINT.NS      0.612722
# 4   BAJAJFINSV.NS      0.612419
# 21  HINDUNILVR.NS      0.606778
# 27    JSWSTEEL.NS      0.570779
# 18    HDFCBANK.NS      0.513138
# 11    DIVISLAB.NS      0.476271

# %%
newlist = top_10[0].tolist()
newlist
# Out:
# ['BAJFINANCE.NS',
#  'TITAN.NS',
#  'NESTLEIND.NS',
#  'RELIANCE.NS',
#  'ASIANPAINT.NS',
#  'BAJAJFINSV.NS',
#  'HINDUNILVR.NS',
#  'JSWSTEEL.NS',
#  'HDFCBANK.NS',
#  'DIVISLAB.NS']

# %%
df2 = pd.DataFrame()
for i in range(len(newlist)):
    df2[newlist[i]] = df1[newlist[i]]
    
df2.head()
# Out:
#             BAJFINANCE.NS    TITAN.NS  NESTLEIND.NS  RELIANCE.NS  \
# Date
# 2016-01-01     601.376648  340.026611   5280.468262   484.996399
# 2016-01-04     597.095032  339.398773   5175.181152   475.419220
# 2016-01-05     591.708618  335.825195   5168.426758   480.124176
# 2016-01-06     602.501160  335.970062   5220.546387   493.044952
# 2016-01-07     602.407532  332.299805   5147.023438   483.993286
#
#             ASIANPAINT.NS  BAJAJFINSV.NS  HINDUNILVR.NS  JSWSTEEL.NS  \
# Date
# 2016-01-01     845.420410    1978.063721     781.844116    92.119720
# 2016-01-04     847.392639    1953.833984     784.080444    93.707375
# 2016-01-05     866.489868    1940.372925     773.994141    97.151772
# 2016-01-06     852.780151    1932.944580     769.521667    94.918304
# 2016-01-07     839.263184    1921.477783     748.710022    92.061424
#
#             HDFCBANK.NS  DIVISLAB.NS
# Date
# 2016-01-01   526.229126  1103.977661
# 2016-01-04   517.408264  1091.822021
# 2016-01-05   513.493347  1089.732788
# 2016-01-06   515.764954  1079.951294
# 2016-01-07   510.496613  1070.217163

# %% [markdown]
# ##### Log returns of stocks

# %%
df3 = pd.DataFrame()
for i in range(len(newlist)):
    b = []
    b.append(np.nan)
    for j in range(df2.shape[0] - 1):
        b.append(np.log(df1[newlist[i]][j+1]/df1[newlist[i]][j]))
    df3[newlist[i]] = b
    
df3 = df3.iloc[1:]
df3.head()
# Out:
#    BAJFINANCE.NS  TITAN.NS  NESTLEIND.NS  RELIANCE.NS  ASIANPAINT.NS  \
# 1      -0.007145 -0.001848     -0.020140    -0.019944       0.002330
# 2      -0.009062 -0.010585     -0.001306     0.009848       0.022286
# 3       0.018075  0.000431      0.010034     0.026556      -0.015949
# 4      -0.000155 -0.010984     -0.014183    -0.018529      -0.015977
# 5       0.033528  0.011416     -0.001136     0.012261       0.002576
#
#    BAJAJFINSV.NS  HINDUNILVR.NS  JSWSTEEL.NS  HDFCBANK.NS  DIVISLAB.NS
# 1      -0.012325       0.002856     0.017088    -0.016904    -0.011072
# 2      -0.006913      -0.012947     0.036098    -0.007595    -0.001915
# 3      -0.003836      -0.005795    -0.023258     0.004414    -0.009017
# 4      -0.005950      -0.027417    -0.030561    -0.010267    -0.009054
# 5       0.037357      -0.012760     0.014317     0.005806     0.002437

# %%
np.random.seed(42)
num_ports = 6000*4
all_weights = np.zeros((num_ports, df3.shape[1]))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for x in range(num_ports):
    if x%6000 == 0:
        print(x)
    # Weights
    weights = np.array(np.random.random(df3.shape[1]))
    weights = weights/np.sum(weights)
    # Save weights
    all_weights[x,:] = weights
    # Expected return
    ret_arr[x] = np.sum((df3.mean() * weights*252))
    # Expected volatility
    vol_arr[x] = np.sqrt(np.dot(weights.T, np.dot(df3.cov()*252, weights)))
    # Sharpe Ratio
    sharpe_arr[x] = ret_arr[x]/vol_arr[x]
# Out:
# 0
# 6000
# 12000
# 18000

# %%
sharpe_arr.max()
p = sharpe_arr.argmax()
print(all_weights[p,:])
# Out:
# [0.16636589 0.09268072 0.1711277  0.16747746 0.06100011 0.0211378
#  0.18748314 0.03721642 0.00687014 0.08864061]

# %%
mr = ret_arr[p]
mv = vol_arr[p]

# %% [markdown]
# ##### Portfolio optimization

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.scatter(mv, mr,c='red', s=50) # red dot
plt.show()

# %%
fy = np.linspace(0.2,0.35,50)

# %%
def get_ret_vol_sr(weights):
    weights = np.array(weights)
    ret = np.sum(df3.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(df3.cov()*252, weights)))
    sr = ret/vol
    return np.array([ret, vol, sr])

def min_vol(weights):
    return get_ret_vol_sr(weights)[1]

def check_sum(weights):
    #return 0 if sum of the weights is 1
    return np.sum(weights)-1

# %%
a = 1/10
c = ((0,1),)
b = []
d = ()
for i in range(10):
    b.append(a)
    d = d+c

# %%
from scipy.optimize import minimize
fx = []

for i in fy:
    print(i)
    cons = ({'type':'eq', 'fun':check_sum},
            {'type':'eq', 'fun': lambda w: get_ret_vol_sr(w)[0] - i})
    
    result = minimize(min_vol, b, method='SLSQP', bounds=d, constraints=cons)
    fx.append(result['fun'])
# Out:
# 0.2
# 0.20306122448979594
# 0.20612244897959184
# 0.20918367346938777
# 0.2122448979591837
# 0.2153061224489796
# 0.21836734693877552
# 0.22142857142857145
# 0.22448979591836735
# 0.22755102040816327
# 0.23061224489795917
# 0.2336734693877551
# 0.23673469387755103
# 0.23979591836734693
# 0.24285714285714285
# 0.24591836734693878
# 0.24897959183673468
# 0.25204081632653064
# 0.25510204081632654
# 0.25816326530612244
# 0.2612244897959184
# 0.2642857142857143
# 0.2673469387755102
# 0.27040816326530615
# 0.27346938775510204
# 0.27653061224489794
# 0.2795918367346939
# 0.2826530612244898
# 0.2857142857142857
# 0.28877551020408165
# 0.29183673469387755
# 0.29489795918367345
# 0.2979591836734694
# 0.3010204081632653
# 0.3040816326530612
# 0.30714285714285716
# 0.31020408163265306
# 0.31326530612244896
# 0.3163265306122449
# 0.3193877551020408
# 0.3224489795918367
# 0.32551020408163267
# 0.32857142857142857
# 0.33163265306122447
# 0.3346938775510204
# 0.3377551020408163
# 0.3408163265306122
# 0.3438775510204082
# 0.3469387755102041
# 0.35

# %%
plt.figure(figsize=(15,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr, cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.plot(fx,fy, 'r--', linewidth=3)
plt.savefig('cover.png')
plt.show()

# %%
mon = all_weights[p,:]*1e7

# %%
num_sto = []
for i in range(len(mon)):
    num_sto.append(mon[i]/df2[newlist[i]][-1])

# %%
num_sto
# Out:
# [314.69010828155854,
#  592.8153303362288,
#  94.11343283710202,
#  846.3014261506152,
#  222.00932166916442,
#  23.73916176291518,
#  793.1877815890455,
#  980.0345356360283,
#  48.039223319022206,
#  231.66653807931388]

# %%
newlist
# Out:
# ['BAJFINANCE.NS',
#  'TITAN.NS',
#  'NESTLEIND.NS',
#  'RELIANCE.NS',
#  'ASIANPAINT.NS',
#  'BAJAJFINSV.NS',
#  'HINDUNILVR.NS',
#  'JSWSTEEL.NS',
#  'HDFCBANK.NS',
#  'DIVISLAB.NS']

# %%
DF = pd.DataFrame()
DF["Name"] = newlist
DF["No. of shares"] = num_sto
DF
# Out:
#             Name  No. of shares
# 0  BAJFINANCE.NS     314.690108
# 1       TITAN.NS     592.815330
# 2   NESTLEIND.NS      94.113433
# 3    RELIANCE.NS     846.301426
# 4  ASIANPAINT.NS     222.009322
# 5  BAJAJFINSV.NS      23.739162
# 6  HINDUNILVR.NS     793.187782
# 7    JSWSTEEL.NS     980.034536
# 8    HDFCBANK.NS      48.039223
# 9    DIVISLAB.NS     231.666538

# %%
import pandas_datareader.data as pdr
import datetime as dt
from statistics import stdev

# %%
fin = dt.datetime(2021, 6, 30)
ini = dt.datetime(2021, 1, 1)

# %%
newdf = pd.DataFrame()
for i in range(len(newlist)):
    try:
        o = pdr.get_data_yahoo(newlist[i],ini,fin)
        newdf[str(newlist[i])] = o["Close"]
    except:
        print('error')
        print(i)
o = pdr.get_data_yahoo('^NSEI',ini,fin)
newdf['Nifty50'] = o["Close"]
newdf.head()
# Out:
#             BAJFINANCE.NS     TITAN.NS  NESTLEIND.NS  RELIANCE.NS  \
# Date
# 2021-01-01    5280.149902  1558.599976  18450.699219  1987.500000
# 2021-01-04    5216.200195  1550.900024  18377.949219  1990.849976
# 2021-01-05    5119.000000  1570.949951  18558.250000  1966.099976
# 2021-01-06    5030.299805  1572.599976  18515.250000  1914.250000
# 2021-01-07    5081.000000  1542.349976  18127.300781  1911.150024
#
#             ASIANPAINT.NS  BAJAJFINSV.NS  HINDUNILVR.NS  JSWSTEEL.NS  \
# Date
# 2021-01-01    2775.550049    8870.450195    2387.550049   389.700012
# 2021-01-04    2753.699951    8898.750000    2426.500000   403.100006
# 2021-01-05    2793.850098    8820.849609    2450.550049   395.250000
# 2021-01-06    2805.350098    8786.349609    2417.300049   401.700012
# 2021-01-07    2792.250000    8988.000000    2368.850098   405.399994
#
#             HDFCBANK.NS  DIVISLAB.NS       Nifty50
# Date
# 2021-01-01  1425.050049  3849.050049           NaN
# 2021-01-04  1416.000000  3862.250000  14132.900391
# 2021-01-05  1426.699951  3842.100098  14199.500000
# 2021-01-06  1420.550049  3879.850098  14146.250000
# 2021-01-07  1416.250000  3803.050049  14137.349609

# %%
x = []

for j in range(newdf.shape[0]):
    initial_value = 0
    for i in range(len(newlist)):
        initial_value += newdf[newlist[i]][j]*num_sto[i] 

    x.append(initial_value)
    
newdf['Portfolio'] = x
newdf.dropna(inplace =True)
newdf.head()
# Out:
#             BAJFINANCE.NS     TITAN.NS  NESTLEIND.NS  RELIANCE.NS  \
# Date
# 2021-01-04    5216.200195  1550.900024  18377.949219  1990.849976
# 2021-01-05    5119.000000  1570.949951  18558.250000  1966.099976
# 2021-01-06    5030.299805  1572.599976  18515.250000  1914.250000
# 2021-01-07    5081.000000  1542.349976  18127.300781  1911.150024
# 2021-01-08    5082.000000  1548.599976  18306.250000  1933.699951
#
#             ASIANPAINT.NS  BAJAJFINSV.NS  HINDUNILVR.NS  JSWSTEEL.NS  \
# Date
# 2021-01-04    2753.699951    8898.750000    2426.500000   403.100006
# 2021-01-05    2793.850098    8820.849609    2450.550049   395.250000
# 2021-01-06    2805.350098    8786.349609    2417.300049   401.700012
# 2021-01-07    2792.250000    8988.000000    2368.850098   405.399994
# 2021-01-08    2844.699951    9171.599609    2391.199951   402.850006
#
#             HDFCBANK.NS  DIVISLAB.NS       Nifty50     Portfolio
# Date
# 2021-01-04  1416.000000  3862.250000  14132.900391  1.008045e+07
# 2021-01-05  1426.699951  3842.100098  14199.500000  1.007206e+07
# 2021-01-06  1420.550049  3879.850098  14146.250000  9.987334e+06
# 2021-01-07  1416.250000  3803.050049  14137.349609  9.895298e+06
# 2021-01-08  1431.650024  3859.149902  14347.250000  9.980211e+06

# %% [markdown]
# ##### Portfolio performnace

# %%
Return_P = ((newdf['Portfolio'][-1] - newdf['Portfolio'][0]) / newdf['Portfolio'][0])*100
Return_B = ((newdf['Nifty50'][-1] - newdf['Nifty50'][0]) / newdf['Nifty50'][0])*100

print('Total Return on Portfolio in %: ', Return_P, '%')
print('Total Return on Benchmark in %: ', Return_B, '%')
# Out:
# Total Return on Portfolio in %:  9.53327669920672 %
# Total Return on Benchmark in %:  11.240435901103435 %

# %%
x = newdf["Portfolio"].pct_change()
vol_P = x.std()*np.sqrt(120)*100
x1 = newdf["Nifty50"].pct_change()
vol_B = x1.std()*np.sqrt(120)*100

print('Volatility of Portfolio in %: ', vol_P, '%')
print('Volatility of Benchmark in %: ', vol_B, '%')
# Out:
# Volatility of Portfolio in %:  11.812840822231156 %
# Volatility of Benchmark in %:  12.61815852180169 %

# %%
rf = 0.06
rfp = ((1+rf)**(180/365) -1)*100

sr = (Return_P - rfp)/vol_P
print('Sharpe Ratio of Portfolio: ', sr)
sb = (Return_B - rfp)/vol_B
print('Sharpe Ratio of Benchmark: ', sb)
# Out:
# Sharpe Ratio of Portfolio:  0.5602426433766825
# Sharpe Ratio of Benchmark:  0.6597806134347695

# %%
newdf["daily_ret_P"] = newdf["Portfolio"].pct_change()
newdf["cum_return"] = (1 + newdf["daily_ret_P"]).cumprod()
newdf["cum_roll_max"] = newdf["cum_return"].cummax()
newdf["drawdown"] = newdf["cum_roll_max"] - newdf["cum_return"]
newdf["drawdown_pct"] = newdf["drawdown"]/newdf["cum_roll_max"]
max_dd = newdf["drawdown_pct"].max()
print('Maximum Draw-down of Portfolio in %: ', max_dd*100, '%')
# Out:
# Maximum Draw-down of Portfolio in %:  8.25575097316012 %

# %%
newdf["daily_ret_B"] = newdf["Nifty50"].pct_change()
newdf["cum_return_B"] = (1 + newdf["daily_ret_B"]).cumprod()
newdf["cum_roll_max_B"] = newdf["cum_return_B"].cummax()
newdf["drawdown_B"] = newdf["cum_roll_max_B"] - newdf["cum_return_B"]
newdf["drawdown_pct_B"] = newdf["drawdown_B"]/newdf["cum_roll_max_B"]
max_dd_B = newdf["drawdown_pct_B"].max()
print('Maximum Draw-down of Benchmark in %: ', max_dd_B*100, '%')
# Out:
# Maximum Draw-down of Benchmark in %:  6.897379751487251 %

# %%
x = newdf["Portfolio"].pct_change()
y = []
count=0
for i in range(len(x)):
    if x[i] < 0:
        y.append(x[i])
        count=count+1
print(y)
neg_vol = stdev(y)*np.sqrt(count)*100

sor = (Return_P - rfp)/neg_vol
print('Sortino Ratio of Portfolio: ', sor)
# Out:
# [-0.0008319039855588795, -0.008412443807508385, -0.009215298605071087, -0.0029185002432647877, -0.007248400702888347, -0.008988521905175628, -0.013303020829562584, -0.0068431688115599965, -0.014222716573226934, -0.01355715205304231, -0.014121934142226289, -0.013041078880813628, -0.017639694819579832, -0.002934528595613828, -0.00703397002349182, -0.0035699055483605635, -0.01130577987042869, -0.011558379272325059, -0.002510030146238962, -0.016167549014670435, -0.026645470330641463, -0.0065220993636553315, -0.0026462138812665126, -0.005491914651507224, -0.007296422677283587, -0.007187404141427822, -0.0145885711919167, -0.0104717803593114, -0.011731660317450321, -0.02330688700446515, -0.000453557403714, -0.01868331095664766, -0.00037801138022153236, -0.026834542681273055, -0.0011516672777529546, -0.01568056832638176, -0.005773229935724267, -0.006689510884711147, -0.009859710781358055, -0.005286922417272688, -0.0010168739660307846, -0.008591327480314326, -0.012661933745930942, -0.002059416686046478, -0.005883569542634026, -0.008017686527939771, -0.0020823986754261448, -0.0025179687115123306, -0.0054249813034313865, -0.004344351464518836, -0.004460418234636054, -0.001113650090460716, -0.006190723531925624, -0.0034396796829322396, -0.0077169562155113836, -0.001870192774286017, -0.00017053474642814148]
# Sortino Ratio of Portfolio:  1.377325155866783

# %%
x = newdf["Nifty50"].pct_change()
y = []
for i in range(len(x)):
    if x[i] < 0:
        y.append(x[i])
print(y)
neg_vol = stdev(y)*np.sqrt(115)*100

sor = (Return_B - rfp)/neg_vol
print('Sortino Ratio of Benchmark: ', sor)
# Out:
# [-0.0037501320469031096, -0.0006291696120880319, -0.011092344158201595, -0.010558650142566628, -0.0037112802046228577, -0.014972171647596122, -0.009254169343308138, -0.019060488041877988, -0.010735650281904374, -0.013240422354072856, -0.0004300136336804483, -0.00018530340410816137, -0.0006590524229219685, -8.162092525865194e-05, -0.006827318687430917, -0.005914312869584326, -0.009074717063029758, -0.020428174591586412, -0.03763569324758598, -0.010812930524138231, -0.009459104528952489, -0.009479506235763657, -0.006749419963093084, -0.001275984104457617, -0.012685759862868795, -0.011102973071742905, -0.000515437423697751, -0.017911176994211853, -0.015430189146808937, -0.010400699094332388, -0.015439860548026041, -0.0026187118170183377, -0.03532558930400764, -0.017676978554819645, -0.004390823034999047, -0.004498133053794207, -0.017710812045177438, -0.00940610742344028, -0.006130201191218876, -0.0103866808073666, -0.0012724250884564858, -0.005159432408138875, -0.00825677606093067, -0.0005101904286871628, -0.001281017305247989, -0.0007333060957773752, -0.006654976944212576, -0.006408632752808119, -0.0048295020472909345, -0.000513069646403852, -0.005439749231269109, -0.0028782098242977616, -0.0041891404314852165, -0.0017112919035373597]
# Sortino Ratio of Benchmark:  0.9834197017890061

# %%
plt.figure(figsize=(14, 7))
for c in df2.columns.values:
    plt.plot(df2.index, df2[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper left', fontsize=12)
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
returns = df2.pct_change()

plt.figure(figsize=(14, 7))
for c in returns.columns.values:
    plt.plot(returns.index, returns[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper right', fontsize=12)
plt.ylabel('daily returns')
# Out:
# Text(0, 0.5, 'daily returns')
